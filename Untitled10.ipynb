# %% [markdown]
# <div style="background-color:#2f2f2f; color:white; padding:20px; border-radius:10px; font-family:'Vazirmatn',Tahoma,sans-serif; line-height:1.8;">
#
# <h1 style="color:#66ccff; text-align:center;">🌐 درس شبکه‌های مخابراتی 🌐</h1>
# <h2 style="color:#ffcc66; text-align:center;">بخش اول: سوالات تشریحی</h2>
#
# <hr style="border:1px solid #555; width:70%;">
#
# <h3 style="color:#ffcc66;">🔹 سوال اول:</h3>
# <p>پروتکل چیست؟</p>
#
# <h3 style="color:#ffcc66;">🔹 سوال دوم:</h3>
# <p>رابطه بین پروتکل و سرویس را تشریح کنید.</p>
#
# <h3 style="color:#ffcc66;">🔹 سوال سوم:</h3>
# <p>پکت‌سوییچینگ چیست و آن را توضیح دهید.</p>
#
# <h3 style="color:#ffcc66;">🔹 سوال چهارم:</h3>
# <p>روش‌های برقراری ارتباط بین دو ماشین را نام ببرید.</p>
#
# <h3 style="color:#ffcc66;">🔹 سوال پنجم:</h3>
# <p>فریم سینکرونایزیشن را توضیح دهید.</p>
#
# <hr style="border:1px solid #666; width:70%;">
#
# <h2 style="color:#66ccff; text-align:center;">🧩 پاسخ‌ها</h2>
#
# <div style="background-color:#404040; color:#cde7ff; padding:10px; border-radius:6px; margin-bottom:10px;">
# <b>پاسخ سوال اول:</b><br>
# پروتکل مجموعه‌ای از قوانین و استانداردهاست که نحوه‌ی ارسال، دریافت و تفسیر داده‌ها بین دستگاه‌های شبکه را مشخص می‌کند.
# نمونه‌ها: TCP، IP، HTTP، FTP
# </div>
#
# <div style="background-color:#404040; color:#cde7ff; padding:10px; border-radius:6px; margin-bottom:10px;">
# <b>پاسخ سوال دوم:</b><br>
# سرویس مجموعه‌ای از عملکردهاست که یک لایه به لایه‌ی بالاتر ارائه می‌دهد، در حالی که پروتکل مجموعه قواعدی است که دو موجودیت در یک لایه برای ارتباط با هم از آن استفاده می‌کنند.
# - سرویس = چی ارائه می‌شود؟
# - پروتکل = چطور ارائه می‌شود؟
# </div>
#
# <div style="background-color:#404040; color:#cde7ff; padding:10px; border-radius:6px; margin-bottom:10px;">
# <b>پاسخ سوال سوم:</b><br>
# پکت‌سوییچینگ روشی برای انتقال داده است که در آن اطلاعات به بسته‌های کوچک تقسیم می‌شوند.
# هر بسته از مسیرهای مختلف عبور می‌کند و در مقصد دوباره سرهم می‌شود.
# این روش در شبکه‌ی اینترنت استفاده می‌شود.
# </div>
#
# <div style="background-color:#404040; color:#cde7ff; padding:10px; border-radius:6px; margin-bottom:10px;">
# <b>پاسخ سوال چهارم:</b><br>
# ۱. راهگزینی مداری<br>
# ۲. راهگزینی بسته‌ای<br>
# ۳. راهگزینی پیامی
# </div>
#
# <div style="background-color:#404040; color:#cde7ff; padding:10px; border-radius:6px; margin-bottom:10px;">
# <b>پاسخ سوال پنجم:</b><br>
# فریم سینکرونایزیشن فرآیندی است برای تشخیص مرز آغاز و پایان هر فریم در جریان داده‌ها.
# این کار باعث می‌شود گیرنده بتواند داده‌ها را به‌درستی تفسیر کند.
# روش‌های رایج شامل استفاده از بیت‌های پرچم یا شمارنده‌ی طول فریم است.
# </div>
#
# <hr style="border:1px solid #999; width:80%;">
#
# <h2 style="color:#ffcc66; text-align:center;">📘 بخش دوم: سوالات تستی</h2>
#
# <div style="background-color:#3a3a3a; padding:10px; border-radius:8px;">
#
# <b style="color:#66ccff;">سوال ۱:</b>
# کدام گزینه بیانگر مفهوم صحیح Packet Switching است؟
# <br> a) ارسال مداوم داده در یک مسیر ثابت
# <br> b) تقسیم داده‌ها به بسته‌های کوچک و ارسال از مسیرهای مختلف
# <br> c) ارسال کل پیام به صورت یکجا
# <br> d) برقراری ارتباط دائمی بین دو گره
# <br><b style="color:#00ff99;">✅ پاسخ صحیح: b</b>
#
# <hr style="border:0.5px solid #555;">
#
# <b style="color:#66ccff;">سوال ۲:</b>
# در Circuit Switching چه زمانی مسیر ارتباطی آزاد می‌شود؟
# <br> a) پس از پایان تبادل داده
# <br> b) پس از ارسال اولین بسته
# <br> c) در حین انتقال داده
# <br> d) هرگز آزاد نمی‌شود
# <br><b style="color:#00ff99;">✅ پاسخ صحیح: a</b>
#
# <hr style="border:0.5px solid #555;">
#
# <b style="color:#66ccff;">سوال ۳:</b>
# کدام روش از اصل “Store and Forward” استفاده می‌کند؟
# <br> a) Circuit Switching
# <br> b) Packet Switching
# <br> c) Message Switching
# <br> d) Frequency Switching
# <br><b style="color:#00ff99;">✅ پاسخ صحیح: c</b>
#
# <hr style="border:0.5px solid #555;">
#
# <b style="color:#66ccff;">سوال ۴:</b>
# بزرگ‌ترین مزیت Packet Switching نسبت به Circuit Switching چیست؟
# <br> a) تاخیر کمتر
# <br> b) استفاده بهینه از منابع شبکه
# <br> c) کیفیت صدای بهتر
# <br> d) نیاز به مسیر اختصاصی
# <br><b style="color:#00ff99;">✅ پاسخ صحیح: b</b>
#
# <hr style="border:0.5px solid #555;">
#
# <b style="color:#66ccff;">سوال ۵:</b>
# کدام یک از روش‌های سوئیچینگ در شبکه تلفنی سنتی استفاده می‌شود؟
# <br> a) Packet Switching
# <br> b) Message Switching
# <br> c) Circuit Switching
# <br> d) Hybrid Switching
# <br><b style="color:#00ff99;">✅ پاسخ صحیح: c</b>
#
# </div>
#
# <hr style="border:1px solid #555; width:70%;">
# <p style="text-align:center; color:#999;">✳️ تهیه و تنظیم: <b>ارشیا – مهندسی برق مخابرات ⚡</b></p>
# </div>
